# %% [markdown]
# Accessing dolly dataset

# %%
from datasets import load_dataset

dolly = load_dataset("databricks/databricks-dolly-15k")

# %% [markdown]
# This code snippet is pulled from my [phi_training](../notebooks/phi_training.ipynb) Jupyter notebook. I then peform a train/val/test split on the data and reformat/tokenize it in order to fine-tune my Phi-1.5 model.
